# %%
import numpy as np
import matplotlib.pyplot as plt

# Try to reproduce the figure shown in images/exercise_1-1.png

# Our data...
x = np.linspace(0, 10, 100)
y1, y2, y3 = np.cos(x), np.cos(x + 1), np.cos(x + 2)
names = ['Signal 1', 'Signal 2', 'Signal 3']

# Can you figure out what to do next to plot x vs y1, y2, and y3 on one figure?
fig,axes = plt.subplots(nrows=3)

for ax, y, name in zip(axes, [y1, y2, y3], names):
    ax.plot(x, y, color='red')
    ax.set(xticks=[], yticks=[], title=name)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# Generate data...
y_raw = np.random.randn(1000).cumsum() + 15
x_raw = np.linspace(0, 24, y_raw.size)

# Get averages of every 100 samples...
x_pos = x_raw.reshape(-1, 100).min(axis=1)
y_avg = y_raw.reshape(-1, 100).mean(axis=1)
y_err = y_raw.reshape(-1, 100).ptp(axis=1)

bar_width = x_pos[1] - x_pos[0]

# Make a made up future prediction with a fake confidence
x_pred = np.linspace(0, 30)
y_max_pred = y_avg[0] + y_err[0] + 2.3 * x_pred
y_min_pred = y_avg[0] - y_err[0] + 1.2 * x_pred

# Just so you don't have to guess at the colors...
barcolor, linecolor, fillcolor = 'wheat', 'salmon', 'lightblue'

# Now you're on your own!
fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))
vert_bars = axes[0].bar(x_pos, y_avg, color='lightblue', align='center')
horiz_bars = axes[1].barh(x_pos, y_avg, color='lightblue', align='center')
plt.show()


fig, ax = plt.subplots()
ax.fill_between(x_pred, y_min_pred, y_max_pred, color='yellow')

# Plot the "centerline" with `plot`
ax.plot(x_pos, y_avg, color='black')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# Generate random data with different ranges...
data1 = np.random.random((10, 10))
data2 = 2 * np.random.random((10, 10))
data3 = 3 * np.random.random((10, 10))

# Set up our figure and axes...
fig, axes = plt.subplots(ncols=3, figsize=plt.figaspect(0.5))
fig.tight_layout() # Make the subplots fill up the figure a bit more...
cax = fig.add_axes([0.25, 0.1, 0.55, 0.03]) # Add an axes for the colorbar

# Now you're on your own
im = axes[0].imshow(data1, cmap='gist_earth')
im = axes[1].imshow(data2, cmap='gist_earth', vmin=-2, vmax=2)
im = axes[2].imshow(data3, cmap='gist_earth', vmax=5)

fig.colorbar(im, cax=cax, orientation='horizontal')
plt.show()

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# read by default 1st sheet of an excel file
df1 = pd.read_csv('C:/Users/XXiong/Documents/ETS/upskill/Data Science Academy/week 4/data for week4/science_response.csv')

nmax=5
nplot=df1.shape[1]-2
rplot=math.ceil(nplot/nmax)

fig, axs = plt.subplots(nrows=rplot, ncols=nmax, figsize=(10, 6))


count=0
for col in df1.columns:
    i=df1.columns.get_loc(col)
    if i>0 and i < nplot:
        count1=int(count / nmax)
        count2=count % nmax
        data=df1.iloc[:,i]
        #color = plt.cm.viridis(norm(thisfrac))
        if max(data)==1: 
            axs[count1, count2].hist(data, bins=2)
        else:
            axs[count1, count2].hist(data, bins=np.arange(min(data), max(data)+1 , 1))
        count=count+1

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# read by default 1st sheet of an excel file
df2 = pd.read_csv('C:/Users/XXiong/Documents/ETS/upskill/Data Science Academy/week 4/data for week4/science_response.csv')

nmax=5

nplot=df2.shape[1]-3
rplot=math.ceil(nplot/nmax)


fig, axs = plt.subplots(nrows=rplot, ncols=nmax, figsize=(10, 6))

y_data=df2.iloc[:,nplot]

count=0
for col in df2.columns:
    i=df2.columns.get_loc(col)
    if i>0 and i < nplot:
        count1=int(count / nmax)
        count2=count % nmax
        data=df2.iloc[:,i]
        axs[count1, count2].scatter(x=data, y=y_data)
        axs[count1, count2].set_xlabel("Item")
        axs[count1, count2].set_ylabel("Total Score")
        count=count+1

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import numpy as np

# read by default 1st sheet of an excel file
df3 = pd.read_csv('C:/Users/XXiong/Documents/ETS/upskill/Data Science Academy/week 4/data for week4/science_response.csv')

nmax=5
nplot=df3.shape[1]-2
rplot=math.ceil(nplot/nmax)

fig, axs = plt.subplots(nrows=rplot, ncols=nmax, figsize=(10, 6))


count=0
for col in df3.columns:
    i=df3.columns.get_loc(col)
    if i>0 and i < nplot:
        count1=int(count / nmax)
        count2=count % nmax
        data=df3.iloc[:,i]
        axs[count1, count2].pie(data)
        #plt.pie(data)
        #plt.show()
        count=count+1

# %%
import ipywidgets as widgets
import pandas as pd

style = {'description_width': 'initial'}
limit_case = widgets.IntSlider(
    value=10,
    min=1,
    max=256,
    step=1,
    description='Max Number of Case:',
    disabled=False,
    style=style)

# %%
def update_df_length(limit):
    
    df = pd.read_csv('C:/Users/XXiong/Documents/ETS/upskill/Data Science Academy/week 4/data for week4/science_response.csv')
    df = df.iloc[0:limit, :]
    
    print("Number of rows in the dataset that have been successfully loaded:"+str(len(df)))


widgets.interactive(update_df_length, limit=limit_case)

#interactive(children=(IntSlider(value=1000, description='Max Number of Case:', max=5000, min=100, style=Slider)))
# Out:
# interactive(children=(IntSlider(value=10, description='Max Number of Case:', max=256, min=1, style=SliderStyle…

# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px

df =  pd.read_csv('C:/Users/XXiong/Documents/ETS/upskill/Data Science Academy/week 4/data for week4/science_response.csv')

st.title('Welcome to the Streamlit Dashboard')

sex = st.sidebar.selectbox("Please select gender: ", ['Male', 'Female'])

fig = px.scatter(df.query('gender==@sex'), x="item1", y="sum_score", color="gender", log_x=True, size_max=60,range_y=[0,30])

st.plotly_chart(fig)
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
